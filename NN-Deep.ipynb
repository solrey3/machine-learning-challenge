# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\budchris\anaconda3\envs\pythonadv\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\budchris\anaconda3\envs\pythonadv\lib\site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\budchris\anaconda3\envs\pythonadv\lib\site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\budchris\anaconda3\envs\pythonadv\lib\site-packages (from scikit-learn->sklearn) (0.15.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\budchris\anaconda3\envs\pythonadv\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\budchris\anaconda3\envs\pythonadv\lib\site-packages (from scikit-learn->sklearn) (1.18.5)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\budchris\anaconda3\envs\pythonadv\lib\site-packages (0.15.1)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
selected_features = df

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# Assign x and y values
X = df.drop("koi_disposition", axis=1)
y = df["koi_disposition"]

print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical


# Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=115, stratify=y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 2700              0              0              0              0   31.804760
# 21                0              0              0              0    4.280964
# 5040              0              1              1              0    0.829019
# 2795              0              0              1              0    1.387838
# 1765              0              0              0              0   14.383227
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 2700         0.000091        -0.000091    190.25413           0.00224
# 21           0.000006        -0.000006    171.89659           0.00115
# 5040         0.000002        -0.000002    131.46667           0.00401
# 2795         0.000006        -0.000006    132.11351           0.00318
# 1765         0.000086        -0.000086    140.57648           0.00530
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 2700          -0.00224  ...            -128      4.235           0.143
# 21            -0.00115  ...            -169      4.564           0.032
# 5040          -0.00401  ...            -255      4.271           0.124
# 2795          -0.00318  ...            -219      4.442           0.054
# 1765          -0.00530  ...            -135      4.249           0.137
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 2700          -0.117     1.356          0.212         -0.259  287.62082
# 21            -0.168     0.831          0.207         -0.069  294.26581
# 5040          -0.186     1.328          0.408         -0.220  296.03485
# 2795          -0.216     1.044          0.335         -0.112  295.64212
# 1765          -0.112     1.291          0.216         -0.216  290.08276
#
#             dec  koi_kepmag
# 2700  43.141647      13.178
# 21    49.314091      15.356
# 5040  45.490822      14.661
# 2795  48.773071      15.167
# 1765  50.863480      13.312
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)
pd.plotting.scatter_matrix(X, c=encoded_y, figsize=(40, 40));

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=10, activation='relu', input_dim=40))
model.add(Dense(units=3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                410
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 443
# Trainable params: 443
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit the model to the training data
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 1.0969 - accuracy: 0.4072
# Epoch 2/100
# 164/164 - 0s - loss: 0.9615 - accuracy: 0.6647
# Epoch 3/100
# 164/164 - 0s - loss: 0.7565 - accuracy: 0.7643
# Epoch 4/100
# 164/164 - 0s - loss: 0.5314 - accuracy: 0.7898
# Epoch 5/100
# 164/164 - 0s - loss: 0.4467 - accuracy: 0.7992
# Epoch 6/100
# 164/164 - 0s - loss: 0.4107 - accuracy: 0.8104
# Epoch 7/100
# 164/164 - 0s - loss: 0.3903 - accuracy: 0.8165
# Epoch 8/100
# 164/164 - 0s - loss: 0.3783 - accuracy: 0.8266
# Epoch 9/100
# 164/164 - 0s - loss: 0.3707 - accuracy: 0.8264
# Epoch 10/100
# 164/164 - 0s - loss: 0.3641 - accuracy: 0.8314
# Epoch 11/100
# 164/164 - 0s - loss: 0.3591 - accuracy: 0.8333
# Epoch 12/100
# 164/164 - 0s - loss: 0.3542 - accuracy: 0.8390
# Epoch 13/100
# 164/164 - 0s - loss: 0.3513 - accuracy: 0.8327
# Epoch 14/100
# 164/164 - 0s - loss: 0.3468 - accuracy: 0.8430
# Epoch 15/100
# 164/164 - 0s - loss: 0.3446 - accuracy: 0.8396
# Epoch 16/100
# 164/164 - 0s - loss: 0.3422 - accuracy: 0.8413
# Epoch 17/100
# 164/164 - 0s - loss: 0.3401 - accuracy: 0.8436
# Epoch 18/100
# 164/164 - 0s - loss: 0.3370 - accuracy: 0.8495
# Epoch 19/100
# 164/164 - 0s - loss: 0.3357 - accuracy: 0.8514
# Epoch 20/100
# 164/164 - 0s - loss: 0.3340 - accuracy: 0.8465
# Epoch 21/100
# 164/164 - 0s - loss: 0.3314 - accuracy: 0.8535
# Epoch 22/100
# 164/164 - 0s - loss: 0.3295 - accuracy: 0.8514
# Epoch 23/100
# 164/164 - 0s - loss: 0.3278 - accuracy: 0.8573
# Epoch 24/100
# 164/164 - 0s - loss: 0.3259 - accuracy: 0.8575
# Epoch 25/100
# 164/164 - 0s - loss: 0.3256 - accuracy: 0.8577
# Epoch 26/100
# 164/164 - 0s - loss: 0.3229 - accuracy: 0.8571
# Epoch 27/100
# 164/164 - 0s - loss: 0.3226 - accuracy: 0.8560
# Epoch 28/100
# 164/164 - 0s - loss: 0.3196 - accuracy: 0.8591
# Epoch 29/100
# 164/164 - 0s - loss: 0.3197 - accuracy: 0.8611
# Epoch 30/100
# 164/164 - 0s - loss: 0.3187 - accuracy: 0.8581
# Epoch 31/100
# 164/164 - 0s - loss: 0.3177 - accuracy: 0.8598
# Epoch 32/100
# 164/164 - 0s - loss: 0.3164 - accuracy: 0.8604
# Epoch 33/100
# 164/164 - 0s - loss: 0.3154 - accuracy: 0.8619
# Epoch 34/100
# 164/164 - 0s - loss: 0.3138 - accuracy: 0.8638
# Epoch 35/100
# 164/164 - 0s - loss: 0.3125 - accuracy: 0.8621
# Epoch 36/100
# 164/164 - 0s - loss: 0.3120 - accuracy: 0.8619
# Epoch 37/100
# 164/164 - 0s - loss: 0.3112 - accuracy: 0.8602
# Epoch 38/100
# 164/164 - 0s - loss: 0.3100 - accuracy: 0.8646
# Epoch 39/100
# 164/164 - 0s - loss: 0.3099 - accuracy: 0.8631
# Epoch 40/100
# 164/164 - 0s - loss: 0.3094 - accuracy: 0.8652
# Epoch 41/100
# 164/164 - 0s - loss: 0.3083 - accuracy: 0.8623
# Epoch 42/100
# 164/164 - 0s - loss: 0.3068 - accuracy: 0.8648
# Epoch 43/100
# 164/164 - 0s - loss: 0.3064 - accuracy: 0.8652
# Epoch 44/100
# 164/164 - 0s - loss: 0.3052 - accuracy: 0.8659
# Epoch 45/100
# 164/164 - 0s - loss: 0.3044 - accuracy: 0.8642
# Epoch 46/100
# 164/164 - 0s - loss: 0.3043 - accuracy: 0.8667
# Epoch 47/100
# 164/164 - 0s - loss: 0.3031 - accuracy: 0.8684
# Epoch 48/100
# 164/164 - 0s - loss: 0.3029 - accuracy: 0.8653
# Epoch 49/100
# 164/164 - 0s - loss: 0.3027 - accuracy: 0.8663
# Epoch 50/100
# 164/164 - 0s - loss: 0.3020 - accuracy: 0.8699
# Epoch 51/100
# 164/164 - 0s - loss: 0.3012 - accuracy: 0.8697
# Epoch 52/100
# 164/164 - 0s - loss: 0.3009 - accuracy: 0.8669
# Epoch 53/100
# 164/164 - 0s - loss: 0.3005 - accuracy: 0.8673
# Epoch 54/100
# 164/164 - 0s - loss: 0.2998 - accuracy: 0.8692
# Epoch 55/100
# 164/164 - 0s - loss: 0.3000 - accuracy: 0.8688
# Epoch 56/100
# 164/164 - 0s - loss: 0.2985 - accuracy: 0.8701
# Epoch 57/100
# 164/164 - 0s - loss: 0.2985 - accuracy: 0.8703
# Epoch 58/100
# 164/164 - 0s - loss: 0.2984 - accuracy: 0.8724
# Epoch 59/100
# 164/164 - 0s - loss: 0.2980 - accuracy: 0.8697
# Epoch 60/100
# 164/164 - 0s - loss: 0.2962 - accuracy: 0.8686
# Epoch 61/100
# 164/164 - 0s - loss: 0.2963 - accuracy: 0.8684
# Epoch 62/100
# 164/164 - 0s - loss: 0.2961 - accuracy: 0.8735
# Epoch 63/100
# 164/164 - 0s - loss: 0.2971 - accuracy: 0.8684
# Epoch 64/100
# 164/164 - 0s - loss: 0.2962 - accuracy: 0.8724
# Epoch 65/100
# 164/164 - 0s - loss: 0.2954 - accuracy: 0.8747
# Epoch 66/100
# 164/164 - 0s - loss: 0.2943 - accuracy: 0.8709
# Epoch 67/100
# 164/164 - 0s - loss: 0.2936 - accuracy: 0.8724
# Epoch 68/100
# 164/164 - 0s - loss: 0.2947 - accuracy: 0.8728
# Epoch 69/100
# 164/164 - 0s - loss: 0.2933 - accuracy: 0.8749
# Epoch 70/100
# 164/164 - 0s - loss: 0.2940 - accuracy: 0.8699
# Epoch 71/100
# 164/164 - 0s - loss: 0.2929 - accuracy: 0.8749
# Epoch 72/100
# 164/164 - 0s - loss: 0.2918 - accuracy: 0.8728
# Epoch 73/100
# 164/164 - 0s - loss: 0.2931 - accuracy: 0.8707
# Epoch 74/100
# 164/164 - 0s - loss: 0.2910 - accuracy: 0.8705
# Epoch 75/100
# 164/164 - 0s - loss: 0.2913 - accuracy: 0.8739
# Epoch 76/100
# 164/164 - 0s - loss: 0.2916 - accuracy: 0.8734
# Epoch 77/100
# 164/164 - 0s - loss: 0.2904 - accuracy: 0.8755
# Epoch 78/100
# 164/164 - 0s - loss: 0.2916 - accuracy: 0.8734
# Epoch 79/100
# 164/164 - 0s - loss: 0.2901 - accuracy: 0.8751
# Epoch 80/100
# 164/164 - 0s - loss: 0.2895 - accuracy: 0.8739
# Epoch 81/100
# 164/164 - 0s - loss: 0.2890 - accuracy: 0.8730
# Epoch 82/100
# 164/164 - 0s - loss: 0.2887 - accuracy: 0.8751
# Epoch 83/100
# 164/164 - 0s - loss: 0.2884 - accuracy: 0.8774
# Epoch 84/100
# 164/164 - 0s - loss: 0.2893 - accuracy: 0.8768
# Epoch 85/100
# 164/164 - 0s - loss: 0.2877 - accuracy: 0.8768
# Epoch 86/100
# 164/164 - 0s - loss: 0.2877 - accuracy: 0.8758
# Epoch 87/100
# 164/164 - 0s - loss: 0.2878 - accuracy: 0.8745
# Epoch 88/100
# 164/164 - 0s - loss: 0.2874 - accuracy: 0.8745
# Epoch 89/100
# 164/164 - 0s - loss: 0.2869 - accuracy: 0.8762
# Epoch 90/100
# 164/164 - 0s - loss: 0.2886 - accuracy: 0.8745
# Epoch 91/100
# 164/164 - 0s - loss: 0.2860 - accuracy: 0.8781
# Epoch 92/100
# 164/164 - 0s - loss: 0.2877 - accuracy: 0.8743
# Epoch 93/100
# 164/164 - 0s - loss: 0.2862 - accuracy: 0.8766
# Epoch 94/100
# 164/164 - 0s - loss: 0.2857 - accuracy: 0.8770
# Epoch 95/100
# 164/164 - 0s - loss: 0.2857 - accuracy: 0.8749
# Epoch 96/100
# 164/164 - 0s - loss: 0.2859 - accuracy: 0.8776
# Epoch 97/100
# 164/164 - 0s - loss: 0.2865 - accuracy: 0.8753
# Epoch 98/100
# 164/164 - 0s - loss: 0.2856 - accuracy: 0.8756
# Epoch 99/100
# 164/164 - 0s - loss: 0.2867 - accuracy: 0.8762
# Epoch 100/100
# 164/164 - 0s - loss: 0.2845 - accuracy: 0.8783

# %%
deep_model = Sequential()
deep_model.add(Dense(units=10, activation='relu', input_dim=40))
deep_model.add(Dense(units=10, activation='relu'))
deep_model.add(Dense(units=3, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 10)                410
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 553
# Trainable params: 553
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 1.0591 - accuracy: 0.4919
# Epoch 2/100
# 164/164 - 0s - loss: 0.6239 - accuracy: 0.7095
# Epoch 3/100
# 164/164 - 0s - loss: 0.4366 - accuracy: 0.7412
# Epoch 4/100
# 164/164 - 0s - loss: 0.4047 - accuracy: 0.7601
# Epoch 5/100
# 164/164 - 0s - loss: 0.3937 - accuracy: 0.7871
# Epoch 6/100
# 164/164 - 0s - loss: 0.3854 - accuracy: 0.7995
# Epoch 7/100
# 164/164 - 0s - loss: 0.3776 - accuracy: 0.8093
# Epoch 8/100
# 164/164 - 0s - loss: 0.3672 - accuracy: 0.8232
# Epoch 9/100
# 164/164 - 0s - loss: 0.3592 - accuracy: 0.8291
# Epoch 10/100
# 164/164 - 0s - loss: 0.3535 - accuracy: 0.8278
# Epoch 11/100
# 164/164 - 0s - loss: 0.3456 - accuracy: 0.8358
# Epoch 12/100
# 164/164 - 0s - loss: 0.3425 - accuracy: 0.8405
# Epoch 13/100
# 164/164 - 0s - loss: 0.3375 - accuracy: 0.8411
# Epoch 14/100
# 164/164 - 0s - loss: 0.3339 - accuracy: 0.8468
# Epoch 15/100
# 164/164 - 0s - loss: 0.3297 - accuracy: 0.8478
# Epoch 16/100
# 164/164 - 0s - loss: 0.3267 - accuracy: 0.8518
# Epoch 17/100
# 164/164 - 0s - loss: 0.3265 - accuracy: 0.8453
# Epoch 18/100
# 164/164 - 0s - loss: 0.3204 - accuracy: 0.8539
# Epoch 19/100
# 164/164 - 0s - loss: 0.3196 - accuracy: 0.8516
# Epoch 20/100
# 164/164 - 0s - loss: 0.3163 - accuracy: 0.8570
# Epoch 21/100
# 164/164 - 0s - loss: 0.3144 - accuracy: 0.8589
# Epoch 22/100
# 164/164 - 0s - loss: 0.3090 - accuracy: 0.8575
# Epoch 23/100
# 164/164 - 0s - loss: 0.3079 - accuracy: 0.8594
# Epoch 24/100
# 164/164 - 0s - loss: 0.3074 - accuracy: 0.8600
# Epoch 25/100
# 164/164 - 0s - loss: 0.3046 - accuracy: 0.8606
# Epoch 26/100
# 164/164 - 0s - loss: 0.3047 - accuracy: 0.8606
# Epoch 27/100
# 164/164 - 0s - loss: 0.3014 - accuracy: 0.8634
# Epoch 28/100
# 164/164 - 0s - loss: 0.2987 - accuracy: 0.8678
# Epoch 29/100
# 164/164 - 0s - loss: 0.2975 - accuracy: 0.8673
# Epoch 30/100
# 164/164 - 0s - loss: 0.2976 - accuracy: 0.8621
# Epoch 31/100
# 164/164 - 0s - loss: 0.2960 - accuracy: 0.8634
# Epoch 32/100
# 164/164 - 0s - loss: 0.2940 - accuracy: 0.8695
# Epoch 33/100
# 164/164 - 0s - loss: 0.2928 - accuracy: 0.8673
# Epoch 34/100
# 164/164 - 0s - loss: 0.2897 - accuracy: 0.8705
# Epoch 35/100
# 164/164 - 0s - loss: 0.2894 - accuracy: 0.8722
# Epoch 36/100
# 164/164 - 0s - loss: 0.2893 - accuracy: 0.8695
# Epoch 37/100
# 164/164 - 0s - loss: 0.2878 - accuracy: 0.8713
# Epoch 38/100
# 164/164 - 0s - loss: 0.2870 - accuracy: 0.8711
# Epoch 39/100
# 164/164 - 0s - loss: 0.2850 - accuracy: 0.8737
# Epoch 40/100
# 164/164 - 0s - loss: 0.2831 - accuracy: 0.8762
# Epoch 41/100
# 164/164 - 0s - loss: 0.2819 - accuracy: 0.8755
# Epoch 42/100
# 164/164 - 0s - loss: 0.2831 - accuracy: 0.8703
# Epoch 43/100
# 164/164 - 0s - loss: 0.2808 - accuracy: 0.8776
# Epoch 44/100
# 164/164 - 0s - loss: 0.2803 - accuracy: 0.8764
# Epoch 45/100
# 164/164 - 0s - loss: 0.2807 - accuracy: 0.8751
# Epoch 46/100
# 164/164 - 0s - loss: 0.2784 - accuracy: 0.8770
# Epoch 47/100
# 164/164 - 0s - loss: 0.2790 - accuracy: 0.8766
# Epoch 48/100
# 164/164 - 0s - loss: 0.2800 - accuracy: 0.8774
# Epoch 49/100
# 164/164 - 0s - loss: 0.2774 - accuracy: 0.8779
# Epoch 50/100
# 164/164 - 0s - loss: 0.2764 - accuracy: 0.8808
# Epoch 51/100
# 164/164 - 0s - loss: 0.2753 - accuracy: 0.8804
# Epoch 52/100
# 164/164 - 0s - loss: 0.2805 - accuracy: 0.8772
# Epoch 53/100
# 164/164 - 0s - loss: 0.2737 - accuracy: 0.8791
# Epoch 54/100
# 164/164 - 0s - loss: 0.2727 - accuracy: 0.8800
# Epoch 55/100
# 164/164 - 0s - loss: 0.2737 - accuracy: 0.8776
# Epoch 56/100
# 164/164 - 0s - loss: 0.2724 - accuracy: 0.8817
# Epoch 57/100
# 164/164 - 0s - loss: 0.2718 - accuracy: 0.8858
# Epoch 58/100
# 164/164 - 0s - loss: 0.2724 - accuracy: 0.8808
# Epoch 59/100
# 164/164 - 0s - loss: 0.2705 - accuracy: 0.8850
# Epoch 60/100
# 164/164 - 0s - loss: 0.2698 - accuracy: 0.8837
# Epoch 61/100
# 164/164 - 0s - loss: 0.2714 - accuracy: 0.8817
# Epoch 62/100
# 164/164 - 0s - loss: 0.2706 - accuracy: 0.8823
# Epoch 63/100
# 164/164 - 0s - loss: 0.2710 - accuracy: 0.8817
# Epoch 64/100
# 164/164 - 0s - loss: 0.2682 - accuracy: 0.8842
# Epoch 65/100
# 164/164 - 0s - loss: 0.2683 - accuracy: 0.8850
# Epoch 66/100
# 164/164 - 0s - loss: 0.2680 - accuracy: 0.8869
# Epoch 67/100
# 164/164 - 0s - loss: 0.2678 - accuracy: 0.8840
# Epoch 68/100
# 164/164 - 0s - loss: 0.2673 - accuracy: 0.8879
# Epoch 69/100
# 164/164 - 0s - loss: 0.2692 - accuracy: 0.8880
# Epoch 70/100
# 164/164 - 0s - loss: 0.2665 - accuracy: 0.8844
# Epoch 71/100
# 164/164 - 0s - loss: 0.2692 - accuracy: 0.8840
# Epoch 72/100
# 164/164 - 0s - loss: 0.2664 - accuracy: 0.8869
# Epoch 73/100
# 164/164 - 0s - loss: 0.2639 - accuracy: 0.8867
# Epoch 74/100
# 164/164 - 0s - loss: 0.2653 - accuracy: 0.8859
# Epoch 75/100
# 164/164 - 0s - loss: 0.2662 - accuracy: 0.8863
# Epoch 76/100
# 164/164 - 0s - loss: 0.2663 - accuracy: 0.8858
# Epoch 77/100
# 164/164 - 0s - loss: 0.2651 - accuracy: 0.8877
# Epoch 78/100
# 164/164 - 0s - loss: 0.2641 - accuracy: 0.8831
# Epoch 79/100
# 164/164 - 0s - loss: 0.2639 - accuracy: 0.8898
# Epoch 80/100
# 164/164 - 0s - loss: 0.2654 - accuracy: 0.8831
# Epoch 81/100
# 164/164 - 0s - loss: 0.2620 - accuracy: 0.8865
# Epoch 82/100
# 164/164 - 0s - loss: 0.2623 - accuracy: 0.8880
# Epoch 83/100
# 164/164 - 0s - loss: 0.2635 - accuracy: 0.8890
# Epoch 84/100
# 164/164 - 0s - loss: 0.2629 - accuracy: 0.8861
# Epoch 85/100
# 164/164 - 0s - loss: 0.2625 - accuracy: 0.8886
# Epoch 86/100
# 164/164 - 0s - loss: 0.2621 - accuracy: 0.8869
# Epoch 87/100
# 164/164 - 0s - loss: 0.2640 - accuracy: 0.8879
# Epoch 88/100
# 164/164 - 0s - loss: 0.2615 - accuracy: 0.8898
# Epoch 89/100
# 164/164 - 0s - loss: 0.2633 - accuracy: 0.8865
# Epoch 90/100
# 164/164 - 0s - loss: 0.2583 - accuracy: 0.8907
# Epoch 91/100
# 164/164 - 0s - loss: 0.2633 - accuracy: 0.8869
# Epoch 92/100
# 164/164 - 0s - loss: 0.2614 - accuracy: 0.8865
# Epoch 93/100
# 164/164 - 0s - loss: 0.2597 - accuracy: 0.8892
# Epoch 94/100
# 164/164 - 0s - loss: 0.2597 - accuracy: 0.8901
# Epoch 95/100
# 164/164 - 0s - loss: 0.2604 - accuracy: 0.8873
# Epoch 96/100
# 164/164 - 0s - loss: 0.2575 - accuracy: 0.8917
# Epoch 97/100
# 164/164 - 0s - loss: 0.2574 - accuracy: 0.8898
# Epoch 98/100
# 164/164 - 0s - loss: 0.2568 - accuracy: 0.8920
# Epoch 99/100
# 164/164 - 0s - loss: 0.2585 - accuracy: 0.8877
# Epoch 100/100
# 164/164 - 0s - loss: 0.2589 - accuracy: 0.8890

# %%
# Neural Networks
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.3027 - accuracy: 0.8598
# Normal Neural Network - Loss: 0.3026544451713562, Accuracy: 0.8598397970199585

# %%
# Deep Learning
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2716 - accuracy: 0.8890
# Deep Neural Network - Loss: 0.2716386020183563, Accuracy: 0.8890160322189331

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
# import joblib
# filename1 = 'solito_nn.sav'
# joblib.dump(model, filename1)
model.save("solito_nn.h5")

# %%
# import joblib
# filename2 = 'solito_deep.sav'
# joblib.dump(deep_model, filename2)
deep_model.save("solito_deep.h5")

# %% [markdown]
# # Statements Regarding Model
#
# Neural Network Accuracy: 0.8598397970199585
#
# Deep Learning Accuracy: 0.8890160322189331
