# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

koi = pd.read_csv('Resources/cumulative.csv')
koi.head(50)
# Out:
#     rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0       1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1       2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2       3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3       4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4       5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# 5       6  10872983  K00756.01  Kepler-228 d       CONFIRMED        CANDIDATE
# 6       7  10872983  K00756.02  Kepler-228 c       CONFIRMED        CANDIDATE
# 7       8  10872983  K00756.03  Kepler-228 b       CONFIRMED        CANDIDATE
# 8       9   6721123  K00114.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9      10  10910878  K00757.01  Kepler-229 c       CONFIRMED        CANDIDATE
# 10     11  11446443  K00001.01    Kepler-1 b       CONFIRMED        CANDIDATE
# ...

# %%
koi.columns
# Out:
# Index(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
#        'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %%
koi = koi.fillna(0)

# %%
data_binary_encoded = pd.get_dummies(koi, columns=["koi_disposition", "koi_pdisposition"])
data_binary_encoded.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name  koi_score  koi_fpflag_nt  \
# 0      1  10797460  K00752.01  Kepler-227 b      1.000              0
# 1      2  10797460  K00752.02  Kepler-227 c      0.969              0
# 2      3  10811496  K00753.01             0      0.000              0
# 3      4  10848459  K00754.01             0      0.000              0
# 4      5  10854555  K00755.01  Kepler-664 b      1.000              0
#
#    koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  ...  \
# 0              0              0              0    9.488036  ...
# 1              0              0              0   54.418383  ...
# 2              1              0              0   19.899140  ...
# 3              1              0              0    1.736952  ...
# 4              0              0              0    2.525592  ...
#
#    koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag  \
# 0          0.105         -0.061  291.93423  48.141651      15.347
# ...

# %%
data_binary_encoded = data_binary_encoded.drop(columns=['koi_disposition_CANDIDATE','koi_disposition_CONFIRMED', 'koi_pdisposition_CANDIDATE'])

# %%
data_binary_encoded.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name  koi_score  koi_fpflag_nt  \
# 0      1  10797460  K00752.01  Kepler-227 b      1.000              0
# 1      2  10797460  K00752.02  Kepler-227 c      0.969              0
# 2      3  10811496  K00753.01             0      0.000              0
# 3      4  10848459  K00754.01             0      0.000              0
# 4      5  10854555  K00755.01  Kepler-664 b      1.000              0
#
#    koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  ...  \
# 0              0              0              0    9.488036  ...
# 1              0              0              0   54.418383  ...
# 2              1              0              0   19.899140  ...
# 3              1              0              0    1.736952  ...
# 4              0              0              0    2.525592  ...
#
#    koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0           0.064          -0.096     0.927          0.105         -0.061
# ...

# %%
# Shape data
X = data_binary_encoded[['koi_fpflag_nt', 'koi_fpflag_ss',
       'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
       'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
       'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
       'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
       'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
       'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
       'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
       'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
       'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
       'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag', 'koi_disposition_FALSE POSITIVE', 'koi_pdisposition_FALSE POSITIVE']]
y = data_binary_encoded['koi_score']
print(X.shape, y.shape)
# Out:
# (9564, 44) (9564,)

# %%
# Split the data into training and testing

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
